# %%
import pandas as pd
import numpy as np
import yfinance as yf

# %%
companies = ["tsla", "aapl", "mcd", "hd"]

# %%
tsla_bal = yf.Ticker('tsla')
tsla_bal_data = tsla_bal.balance_sheet.to_dict()

# %%
tsla_bal_df = pd.DataFrame.from_dict(tsla_bal_data, orient='index')

# %%
tsla_bal_df = tsla_bal_df.transpose()

# %%
tsla_bal_df
# Out:
#             Ordinary Shares Number  Share Issued    Total Debt  \
# 2022-12-31            3.164000e+09  3.164000e+09  5.748000e+09
# 2021-12-31            3.099000e+09  3.099000e+09  8.873000e+09
# 2020-12-31            2.880000e+09  2.880000e+09  1.327900e+10
#
#             Tangible Book Value  Invested Capital  Working Capital  \
# 2022-12-31         4.411100e+10      4.674900e+10     1.420800e+10
# 2021-12-31         2.847200e+10      3.553100e+10     7.395000e+09
# 2020-12-31         2.170500e+10      3.249600e+10     1.246900e+10
#
#             Net Tangible Assets  Capital Lease Obligations  \
# 2022-12-31         4.411100e+10               3.703000e+09
# 2021-12-31         2.847200e+10               3.531000e+09
# 2020-12-31         2.170500e+10               3.008000e+09
#
#             Common Stock Equity  Total Capitalization  ...     Inventory  \
# 2022-12-31         4.470400e+10          4.573300e+10  ...  1.283900e+10
# ...

# %%
mcd_bal = yf.Ticker('mcd')
mcd_bal_data = mcd_bal.balance_sheet.to_dict()

# %%
mcd_bal_df = pd.DataFrame.from_dict(mcd_bal_data, orient='index')

# %%
mcd_bal_df = mcd_bal_df.transpose()

# %%
mcd_bal_df
# Out:
#             Treasury Shares Number  Ordinary Shares Number  Share Issued  \
# 2022-12-31             929300000.0             731300000.0  1.660600e+09
# 2021-12-31             915800000.0             744800000.0  1.660600e+09
# 2020-12-31             915200000.0             745400000.0  1.660600e+09
#
#                 Net Debt    Total Debt  Tangible Book Value  Invested Capital  \
# 2022-12-31  3.331970e+10  4.869900e+10        -8.903800e+09      2.990010e+10
# 2021-12-31  3.091350e+10  4.934910e+10        -7.383500e+09      3.102170e+10
# 2020-12-31  3.399130e+10  5.146320e+10        -1.059800e+10      2.961550e+10
#
#             Working Capital  Net Tangible Assets  Capital Lease Obligations  \
# 2022-12-31     1.622100e+09        -8.903800e+09               1.279550e+10
# 2021-12-31     3.128500e+09        -7.383500e+09               1.372640e+10
# 2020-12-31     6.200000e+07        -1.059800e+10               1.402280e+10
#
# ...

# %%
hd_bal = yf.Ticker('hd')
hd_bal_data = hd_bal.balance_sheet.to_dict()

# %%
hd_bal_df = pd.DataFrame.from_dict(hd_bal_data, orient='index')

# %%
hd_bal_df = hd_bal_df.transpose()

# %%
hd_bal_df
# Out:
#             Treasury Shares Number  Ordinary Shares Number  Share Issued  \
# 2023-01-31             778000000.0            1.016000e+09  1.794000e+09
# 2022-01-31             757000000.0            1.035000e+09  1.792000e+09
# 2021-01-31             712000000.0            1.077000e+09  1.789000e+09
# 2020-01-31             709000000.0            1.077000e+09  1.786000e+09
#
#                 Net Debt    Total Debt  Tangible Book Value  Invested Capital  \
# 2023-01-31  4.043600e+10  5.036400e+10        -9.205000e+09      4.475500e+10
# 2022-01-31  3.774300e+10  4.626900e+10        -1.264800e+10      3.839000e+10
# 2021-01-31  2.934300e+10  4.342200e+10        -3.827000e+09      4.053700e+10
# 2020-01-31  2.935000e+10  3.737700e+10        -5.370000e+09      2.836700e+10
#
#             Working Capital  Net Tangible Assets  Capital Lease Obligations  \
# 2023-01-31     9.361000e+09        -9.205000e+09               7.171000e+09
# ...

# %%
aapl_bal = yf.Ticker('aapl')
aapl_bal_data = aapl_bal.balance_sheet.to_dict()

# %%
aapl_bal_df = pd.DataFrame.from_dict(aapl_bal_data, orient='index')

# %%
aapl_bal_df = aapl_bal_df.transpose()

# %%
aapl_bal_df
# Out:
#             Treasury Shares Number  Ordinary Shares Number  Share Issued  \
# 2023-09-30                     0.0            1.555006e+10  1.555006e+10
# 2022-09-30                     NaN            1.594342e+10  1.594342e+10
# 2021-09-30                     NaN            1.642679e+10  1.642679e+10
# 2020-09-30                     NaN            1.697676e+10  1.697676e+10
#
#                 Net Debt    Total Debt  Tangible Book Value  Invested Capital  \
# 2023-09-30  8.112300e+10  1.110880e+11         6.214600e+10      1.732340e+11
# 2022-09-30  9.642300e+10  1.200690e+11         5.067200e+10      1.707410e+11
# 2021-09-30  8.977900e+10  1.247190e+11         6.309000e+10      1.878090e+11
# 2020-09-30  7.442000e+10  1.124360e+11         6.533900e+10      1.777750e+11
#
#             Working Capital  Net Tangible Assets  Common Stock Equity  ...  \
# 2023-09-30    -1.742000e+09         6.214600e+10         6.214600e+10  ...
# ...
